# %%
import glob
import os
import random
import shutil

src_dir = '/home/melan/supervised-vs-SSL/data/fma_data/fma_small'
dst_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset'
target_size = 1900 * 1024 * 1024  # 1900 MB in bytes

# Recursively find all .mp3 files
all_files = glob.glob(os.path.join(src_dir, '**', '*.mp3'), recursive=True)
random.shuffle(all_files)

selected = []
total_size = 0
for f in all_files:
    size = os.path.getsize(f)
    if total_size + size > target_size:
        break
    selected.append(f)
    total_size += size

os.makedirs(dst_dir, exist_ok=True)
for f in selected:
    shutil.copy2(f, dst_dir)

print(f"Moved {len(selected)} files totaling {total_size / (1024*1024):.2f} MB to {dst_dir}")

# %%
import glob
import os
import random
import shutil
from pydub import AudioSegment

# Paths
speech_dir = '/home/melan/supervised-vs-SSL/data/speech_data/speechcommands'
music_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset'
dst_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/500_wav_subset'
os.makedirs(dst_dir, exist_ok=True)

# Collect all wav and mp3 files
speech_files = glob.glob(os.path.join(speech_dir, '**', '*.wav'), recursive=True)
music_files = glob.glob(os.path.join(music_dir, '**', '*.mp3'), recursive=True)

# Randomly select 250 from each
speech_selected = random.sample(speech_files, 250)
music_selected = random.sample(music_files, 250)

# Combine and shuffle
all_selected = speech_selected + music_selected
random.shuffle(all_selected)

# Copy speech wav files and convert music mp3 files to wav
for f in all_selected:
    base = os.path.splitext(os.path.basename(f))[0]
    dst_path = os.path.join(dst_dir, f"{base}.wav")
    if f.endswith('.wav'):
        shutil.copy2(f, dst_path)
    elif f.endswith('.mp3'):
        audio = AudioSegment.from_mp3(f)
        audio.export(dst_path, format="wav")

print(f"Copied and converted {len(all_selected)} files to {dst_dir}")

# %%
import glob
import os
from pydub import AudioSegment

src_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset'
dst_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset_wav'
os.makedirs(dst_dir, exist_ok=True)

mp3_files = glob.glob(os.path.join(src_dir, '*.mp3'))

for mp3_path in mp3_files:
    base = os.path.splitext(os.path.basename(mp3_path))[0]
    wav_path = os.path.join(dst_dir, f"{base}.wav")
    try:
        audio = AudioSegment.from_mp3(mp3_path)
        audio.export(wav_path, format="wav")
        print(f"Converted: {mp3_path} -> {wav_path}")
    except Exception as e:
        print(f"Error converting {mp3_path}: {e}")

print(f"Finished converting {len(mp3_files)} files to {dst_dir}")

# %%
import os
import glob
import numpy as np
import soundfile as sf
import random

speech_dir = '/home/melan/supervised-vs-SSL/data/speech_data/speechcommands'
output_speech_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_speech'
os.makedirs(output_speech_dir, exist_ok=True)

target_sr = 16000
target_len = 10 * target_sr  # 10 seconds

# Group speech files by word
speech_files = glob.glob(os.path.join(speech_dir, '**', '*.wav'), recursive=True)
word_to_files = {}
for f in speech_files:
    word = os.path.basename(f).split('_')[0]
    word_to_files.setdefault(word, []).append(f)

# Concatenate 10 files per word, save as one 10s file
speech_out_paths = []
for word, files in word_to_files.items():
    random.shuffle(files)
    for i in range(0, len(files) - 9, 10):
        group = files[i:i+10]
        audio_concat = []
        for f in group:
            y, sr = sf.read(f)
            if len(y.shape) > 1:
                y = np.mean(y, axis=1)
            if sr != target_sr:
                import librosa
                y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
            # Pad/truncate to 1s
            if len(y) < target_sr:
                y = np.pad(y, (0, target_sr - len(y)), mode='constant')
            elif len(y) > target_sr:
                y = y[:target_sr]
            audio_concat.append(y)
        y_out = np.concatenate(audio_concat)
        out_name = f"{word}_{i//10:04d}.wav"
        out_path = os.path.join(output_speech_dir, out_name)
        sf.write(out_path, y_out, target_sr)
        speech_out_paths.append((out_path, word))
print(f"Created {len(speech_out_paths)} 10s speech files.")
# Out:
# Created 6459 10s speech files.

# %%
music_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset_wav'
output_music_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_music'
os.makedirs(output_music_dir, exist_ok=True)

music_files = glob.glob(os.path.join(music_dir, '*.wav'))
music_out_paths = []
for f in music_files:
    y, sr = sf.read(f)
    if len(y.shape) > 1:
        y = np.mean(y, axis=1)
    if sr != target_sr:
        import librosa
        y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    total_len = len(y)
    num_chunks = total_len // target_len
    for i in range(num_chunks):
        chunk = y[i*target_len:(i+1)*target_len]
        out_name = f"{os.path.splitext(os.path.basename(f))[0]}_{i:04d}.wav"
        out_path = os.path.join(output_music_dir, out_name)
        sf.write(out_path, chunk, target_sr)
        music_out_paths.append((out_path, 'music'))
print(f"Created {len(music_out_paths)} 10s music files.")
# Out:
# Created 4842 10s music files.

# %%
import csv

label_csv_path = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_labels_mapping.csv'
with open(label_csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['file_path', 'label'])
    for path, label in speech_out_paths + music_out_paths:
        writer.writerow([path, label])
print(f"Saved label CSV to {label_csv_path}")
# Out:
# Saved label CSV to /home/melan/supervised-vs-SSL/data/preprocessed/10s_labels_mapping.csv

# %%
import os
import glob
import numpy as np
import soundfile as sf

music_dir = '/home/melan/supervised-vs-SSL/data/fma_data/1900MB_subset_wav'
output_music_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_music'
os.makedirs(output_music_dir, exist_ok=True)

target_sr = 16000
target_len = 10 * target_sr  # 10 seconds

music_files = glob.glob(os.path.join(music_dir, '*.wav'))
music_out_paths = []
for f in music_files:
    y, sr = sf.read(f)
    if len(y.shape) > 1:
        y = np.mean(y, axis=1)
    if sr != target_sr:
        import librosa
        y = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    total_len = len(y)
    num_chunks = total_len // target_len
    for i in range(num_chunks):
        chunk = y[i*target_len:(i+1)*target_len]
        out_name = f"{os.path.splitext(os.path.basename(f))[0]}_{i:04d}.wav"
        out_path = os.path.join(output_music_dir, out_name)
        sf.write(out_path, chunk, target_sr)
        music_out_paths.append(out_path)
print(f"Created {len(music_out_paths)} 10s music files.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 16
#      14 music_out_paths = []
#      15 for f in music_files:
# ---> 16     y, sr = sf.read(f)
#      17     if len(y.shape) > 1:
#      18         y = np.mean(y, axis=1)
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/soundfile.py:308, in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     305 with SoundFile(file, 'r', samplerate, channels,
#     306                subtype, endian, format, closefd) as f:
#     307     frames = f._prepare_read(start, stop, frames)
# --> 308     data = f.read(frames, dtype, always_2d, fill_value, out)
#     309 return data, f.samplerate
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/soundfile.py:942, in SoundFile.read(self, frames, dtype, always_2d, fill_value, out)
#     940     if frames < 0 or frames > len(out):
#     941         frames = len(out)
# --> 942 frames = self._array_io('read', out, frames)
#     943 if len(out) > frames:
#     944     if fill_value is None:
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/soundfile.py:1394, in SoundFile._array_io(self, action, array, frames)
#    1392 assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1393 cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1394 return self._cdata_io(action, cdata, ctype, frames)
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/soundfile.py:1403, in SoundFile._cdata_io(self, action, data, ctype, frames)
#    1401     curr = self.tell()
#    1402 func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1403 frames = func(self._file, data, frames)
#    1404 _error_check(self._errorcode)
#    1405 if self.seekable():
#
# KeyboardInterrupt:

# %%
import pandas as pd

music_metadata_path = '/home/melan/supervised-vs-SSL/data/fma_data/fma_metadata/tracks.csv'
genre_map_path = '/home/melan/supervised-vs-SSL/data/fma_data/fma_metadata/raw_genres.csv'

music_metadata = pd.read_csv(music_metadata_path, index_col=0, header=[0, 1])
genre_map = pd.read_csv(genre_map_path, index_col='genre_id')['genre_title'].to_dict()

def get_genre_label(filename):
    # FMA track id is the first 6 digits of the filename
    base = os.path.basename(filename)
    track_id_str = base[:6]
    try:
        track_id = int(track_id_str)
    except ValueError:
        return 'unknown'
    if track_id in music_metadata.index:
        genres_str = music_metadata.loc[track_id, ('track', 'genres')]
        genre_ids = eval(genres_str) if pd.notnull(genres_str) else []
        genres = [genre_map.get(gid, 'unknown') for gid in genre_ids]
        return '|'.join(genres) if genres else 'unknown'
    else:
        return 'unknown'

music_labeled = [(path, get_genre_label(path)) for path in music_out_paths]

import csv

label_csv_path = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_labels_mapping.csv'
with open(label_csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['file_path', 'label'])
    # speech_out_paths is [(path, word)]
    for path, label in speech_out_paths:
        writer.writerow([path, label])
    # music_labeled is [(path, genre_label)]
    for path, label in music_labeled:
        writer.writerow([path, label])
print(f"Saved label CSV to {label_csv_path}")

# %%
import csv

label_csv_path = '/home/melan/supervised-vs-SSL/data/preprocessed/10s_labels_mapping.csv'
with open(label_csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['file_path', 'label'])
    # speech_out_paths is [(path, word)]
    for path, label in speech_out_paths:
        writer.writerow([path, label])
    # music_labeled is [(path, genre_label)]
    for path, label in music_labeled:
        writer.writerow([path, label])
print(f"Saved label CSV to {label_csv_path}")
# Out:
# Saved label CSV to /home/melan/supervised-vs-SSL/data/preprocessed/10s_labels_mapping.csv

# %%
import os
import pandas as pd
import glob
import csv

# --- Paths ---
speech_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/noisy_passt_speech'
music_dir = '/home/melan/supervised-vs-SSL/data/preprocessed/noisy_passt_music'
music_metadata_path = '/home/melan/supervised-vs-SSL/data/fma_data/fma_metadata/tracks.csv'
genre_map_path = '/home/melan/supervised-vs-SSL/data/fma_data/fma_metadata/raw_genres.csv'
output_csv_path = '/home/melan/supervised-vs-SSL/data/passt_labels_mapping.csv'  # <-- Change this to wherever you want

# --- Load metadata ---
music_metadata = pd.read_csv(music_metadata_path, index_col=0, header=[0, 1])
genre_map = pd.read_csv(genre_map_path, index_col='genre_id')['genre_title'].to_dict()

# --- Collect all .npy files ---
speech_files = glob.glob(os.path.join(speech_dir, '**', '*.npy'), recursive=True)
music_files = glob.glob(os.path.join(music_dir, '**', '*.npy'), recursive=True)
all_files = speech_files + music_files

# --- Write CSV ---
with open(output_csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['file_path', 'label'])  # header

    for idx, spec_path in enumerate(all_files):
        fname = os.path.basename(spec_path)
        if spec_path.startswith(speech_dir):
            label = fname.split('_')[0]
        elif spec_path.startswith(music_dir):
            track_id_str = fname[3:6]
            try:
                track_id = int(track_id_str)
            except ValueError:
                track_id = None
            if track_id is not None and track_id in music_metadata.index:
                genres_str = music_metadata.loc[track_id, ('track', 'genres')]
                genre_ids = eval(genres_str) if pd.notnull(genres_str) else []
                genres = [genre_map.get(gid, 'unknown') for gid in genre_ids]
            else:
                genres = []
            label = '|'.join(genres)  # join multiple genres as a string
        else:
            label = 'unknown'
        writer.writerow([spec_path, label])
        if idx < 5 or idx % 100 == 0:
            print(f"Processed {idx+1} files...", flush=True)

print(f"Labels CSV saved to: {output_csv_path}")

# %%
ulimit -n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ulimit -n
#
# NameError: name 'ulimit' is not defined

# %%
import os
import numpy as np
import pandas as pd

# Paths
label_csv = 'passt_labels_mapping.csv'  # Your CSV with file_path and label
# If you want to use both folders directly:
speech_folder = '/noisy_passt_speech/'
music_folder = '/noisy_passt_music/'

# Load label CSV
df = pd.read_csv(label_csv)

# Prepare lists for features and labels
X = []
y = []

for idx, row in df.iterrows():
    npy_path = row['file_path']
    label = row['label']
    if not os.path.exists(npy_path):
        print(f"Missing file: {npy_path}")
        continue
    spec = np.load(npy_path)
    X.append(spec.flatten())  # Flatten for classifier; for PaSST you may want to keep original shape
    y.append(label)
    if idx < 5:
        print(f"Loaded {npy_path}, label: {label}")

X = np.array(X)
y = np.array(y)
print(f"Loaded {len(X)} samples.")

# Now you can train a classifier, or pass X/y to your fine-tuning script
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 24
#      22     print(f"Missing file: {npy_path}")
#      23     continue
# ---> 24 spec = np.load(npy_path)
#      25 X.append(spec.flatten())  # Flatten for classifier; for PaSST you may want to keep original shape
#      26 y.append(label)
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/numpy/lib/npyio.py:462, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
# --> 462         raise ValueError("Cannot load file containing pickled data "
#     463                          "when allow_pickle=False")
#     464     try:
#     465         return pickle.load(fid, **pickle_kwargs)
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
import os
import numpy as np

features_dir = '/home/melan/supervised-vs-SSL/data/results/byola/final_embeddings'
embedding_files = sorted([f for f in os.listdir(features_dir) if f.endswith('.npy')])

X = []
file_basenames = []
for i, emb_file in enumerate(embedding_files):
    emb_path = os.path.join(features_dir, emb_file)
    try:
        arr = np.load(emb_path)
        print(f"[{i+1}/{len(embedding_files)}] Loaded {emb_file}, shape: {arr.shape}")
        X.append(arr.flatten())
        file_basenames.append(os.path.splitext(emb_file)[0])
    except Exception as e:
        print(f"Error loading {emb_file}: {e}")

print("Finished loading all files. Now converting to numpy array...")
try:
    X = np.array(X)
    print(f"X shape: {X.shape}")
except Exception as e:
    print(f"Error converting X to numpy array: {e}")
# Out:
# Trying to load 000140_0000_bus01_12.wav.npy (1/55563)
# Loaded 000140_0000_bus01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0001_bus02_12.wav.npy (2/55563)
# Loaded 000140_0001_bus02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0002_bus03_12.wav.npy (3/55563)
# Loaded 000140_0002_bus03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0003_bus04_12.wav.npy (4/55563)
# Loaded 000140_0003_bus04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0004_bus05_12.wav.npy (5/55563)
# Loaded 000140_0004_bus05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0005_bus06_12.wav.npy (6/55563)
# Loaded 000140_0005_bus06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0006_bus07_12.wav.npy (7/55563)
# Loaded 000140_0006_bus07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0007_bus08_12.wav.npy (8/55563)
# Loaded 000140_0007_bus08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0008_bus09_12.wav.npy (9/55563)
# Loaded 000140_0008_bus09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0009_bus10_12.wav.npy (10/55563)
# Loaded 000140_0009_bus10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0010_busystreet01_12.wav.npy (11/55563)
# Loaded 000140_0010_busystreet01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0011_busystreet02_12.wav.npy (12/55563)
# Loaded 000140_0011_busystreet02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0012_busystreet03_12.wav.npy (13/55563)
# Loaded 000140_0012_busystreet03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0013_busystreet04_12.wav.npy (14/55563)
# Loaded 000140_0013_busystreet04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0014_busystreet05_12.wav.npy (15/55563)
# Loaded 000140_0014_busystreet05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0015_busystreet06_12.wav.npy (16/55563)
# Loaded 000140_0015_busystreet06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0016_busystreet07_12.wav.npy (17/55563)
# Loaded 000140_0016_busystreet07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0017_busystreet08_12.wav.npy (18/55563)
# Loaded 000140_0017_busystreet08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0018_busystreet09_12.wav.npy (19/55563)
# Loaded 000140_0018_busystreet09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0019_busystreet10_12.wav.npy (20/55563)
# Loaded 000140_0019_busystreet10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0020_office01_12.wav.npy (21/55563)
# Loaded 000140_0020_office01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0021_office02_12.wav.npy (22/55563)
# Loaded 000140_0021_office02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0022_office03_12.wav.npy (23/55563)
# Loaded 000140_0022_office03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0023_office04_12.wav.npy (24/55563)
# Loaded 000140_0023_office04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0024_office05_12.wav.npy (25/55563)
# Loaded 000140_0024_office05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0025_office06_12.wav.npy (26/55563)
# Loaded 000140_0025_office06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0026_office07_12.wav.npy (27/55563)
# Loaded 000140_0026_office07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0027_office08_12.wav.npy (28/55563)
# Loaded 000140_0027_office08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0028_office09_12.wav.npy (29/55563)
# Loaded 000140_0028_office09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000140_0029_office10_12.wav.npy (30/55563)
# Loaded 000140_0029_office10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 
_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0006_restaurant09_12.wav.npy (69/55563)
# Loaded 000200_0006_restaurant09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0007_restaurant10_12.wav.npy (70/55563)
# Loaded 000200_0007_restaurant10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0008_supermarket01_12.wav.npy (71/55563)
# Loaded 000200_0008_supermarket01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0009_supermarket02_12.wav.npy (72/55563)
# Loaded 000200_0009_supermarket02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0010_supermarket03_12.wav.npy (73/55563)
# Loaded 000200_0010_supermarket03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0011_supermarket04_12.wav.npy (74/55563)
# Loaded 000200_0011_supermarket04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0012_supermarket05_12.wav.npy (75/55563)
# Loaded 000200_0012_supermarket05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0013_supermarket06_12.wav.npy (76/55563)
# Loaded 000200_0013_supermarket06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0014_supermarket07_12.wav.npy (77/55563)
# Loaded 000200_0014_supermarket07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0015_supermarket08_12.wav.npy (78/55563)
# Loaded 000200_0015_supermarket08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0016_supermarket09_12.wav.npy (79/55563)
# Loaded 000200_0016_supermarket09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0017_supermarket10_12.wav.npy (80/55563)
# Loaded 000200_0017_supermarket10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0018_tube01_12.wav.npy (81/55563)
# Loaded 000200_0018_tube01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0019_tube02_12.wav.npy (82/55563)
# Loaded 000200_0019_tube02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0020_tube03_12.wav.npy (83/55563)
# Loaded 000200_0020_tube03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0021_tube04_12.wav.npy (84/55563)
# Loaded 000200_0021_tube04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0022_tube05_12.wav.npy (85/55563)
# Loaded 000200_0022_tube05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0023_tube06_12.wav.npy (86/55563)
# Loaded 000200_0023_tube06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0024_tube07_12.wav.npy (87/55563)
# Loaded 000200_0024_tube07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0025_tube08_12.wav.npy (88/55563)
# Loaded 000200_0025_tube08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0026_tube09_12.wav.npy (89/55563)
# Loaded 000200_0026_tube09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0027_tube10_12.wav.npy (90/55563)
# Loaded 000200_0027_tube10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0028_tubestation01_12.wav.npy (91/55563)
# Loaded 000200_0028_tubestation01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0029_tubestation02_12.wav.npy (92/55563)
# Loaded 000200_0029_tubestation02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000200_0030_tubestation03_12.wav.npy (93/55563)
# Loaded 000200_0030_tubestation03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0000_tubestation04_12.wav.npy (94/55563)
# Loaded 000210_0000_tubestation04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0001_tubestation05_12.wav.npy (95/55563)
# Loaded 000210_0001_tubestation05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0002_tubestation06_12.wav.npy (96/55563)
# Loaded 000210_0002_tubestation06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0003_tubestation07_12.wav.npy (97/55563)
# Loaded 000210_0003_tubestation07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0004_tubestation08_12.wav.npy (98/55563)
# Loaded 000210_0004_tubestation08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0005_tubestation09_12.wav.npy (99/55563)
# Loaded 000210_0005_tubestation09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0006_tubestation10_12.wav.npy (100/55563)
# Loaded 000210_0006_tubestation10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0007_bus01_12.wav.npy (101/55563)
# Loaded 000210_0007_bus01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0008_bus02_12.wav.npy (102/55563)
# Loaded 000210_0008_bus02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0009_bus03_12.wav.npy (103/55563)
# Loaded 000210_0009_bus03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0010_bus04_12.wav.npy (104/55563)
# Loaded 000210_0010_bus04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0011_bus05_12.wav.npy (105/55563)
# Loaded 000210_0011_bus05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0012_bus06_12.wav.npy (106/55563)
# Loaded 000210_0012_bus06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0013_bus07_12.wav.npy (107/55563)
# Loaded 000210_0013_bus07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0014_bus08_12.wav.npy (108/55563)
# Loaded 000210_0014_bus08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0015_bus09_12.wav.npy (109/55563)
# Loaded 000210_0015_bus09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0016_bus10_12.wav.npy (110/55563)
# Loaded 000210_0016_bus10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0017_busystreet01_12.wav.npy (111/55563)
# Loaded 000210_0017_busystreet01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0018_busystreet02_12.wav.npy (112/55563)
# Loaded 000210_0018_busystreet02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0019_busystreet03_12.wav.npy (113/55563)
# Loaded 000210_0019_busystreet03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0020_busystreet04_12.wav.npy (114/55563)
# Loaded 000210_0020_busystreet04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0021_busystreet05_12.wav.npy (115/55563)
# Loaded 000210_0021_busystreet05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0022_busystreet06_12.wav.npy (116/55563)
# Loaded 000210_0022_busystreet06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0023_busystreet07_12.wav.npy (117/55563)
# Loaded 000210_0023_busystreet07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0024_busystreet08_12.wav.npy (118/55563)
# Loaded 000210_0024_busystreet08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0025_busystreet09_12.wav.npy (119/55563)
# Loaded 000210_0025_busystreet09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0026_busystreet10_12.wav.npy (120/55563)
# Loaded 000210_0026_busystreet10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0027_office01_12.wav.npy (121/55563)
# Loaded 000210_0027_office01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0028_office02_12.wav.npy (122/55563)
# Loaded 000210_0028_office02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0029_office03_12.wav.npy (123/55563)
# Loaded 000210_0029_office03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000210_0030_office04_12.wav.npy (124/55563)
# Loaded 000210_0030_office04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0000_office05_12.wav.npy (125/55563)
# Loaded 000256_0000_office05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0001_office06_12.wav.npy (126/55563)
# Loaded 000256_0001_office06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0002_office07_12.wav.npy (127/55563)
# Loaded 000256_0002_office07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0003_office08_12.wav.npy (128/55563)
# Loaded 000256_0003_office08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0004_office09_12.wav.npy (129/55563)
# Loaded 000256_0004_office09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0005_office10_12.wav.npy (130/55563)
# Loaded 000256_0005_office10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0006_openairmarket01_12.wav.npy (131/55563)
# Loaded 000256_0006_openairmarket01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0007_openairmarket02_12.wav.npy (132/55563)
# Loaded 000256_0007_openairmarket02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0008_openairmarket03_12.wav.npy (133/55563)
# Loaded 000256_0008_openairmarket03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0009_openairmarket04_12.wav.npy (134/55563)
# Loaded 000256_0009_openairmarket04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0010_openairmarket05_12.wav.npy (135/55563)
# Loaded 000256_0010_openairmarket05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0011_openairmarket06_12.wav.npy (136/55563)
# Loaded 000256_0011_openairmarket06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0012_openairmarket07_12.wav.npy (137/55563)
# Loaded 000256_0012_openairmarket07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0013_openairmarket08_12.wav.npy (138/55563)
# Loaded 000256_0013_openairmarket08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0014_openairmarket09_12.wav.npy (139/55563)
# Loaded 000256_0014_openairmarket09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0015_openairmarket10_12.wav.npy (140/55563)
# Loaded 000256_0015_openairmarket10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0016_park01_12.wav.npy (141/55563)
# Loaded 000256_0016_park01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0017_park02_12.wav.npy (142/55563)
# Loaded 000256_0017_park02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0018_park03_12.wav.npy (143/55563)
# Loaded 000256_0018_park03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0019_park04_12.wav.npy (144/55563)
# Loaded 000256_0019_park04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0020_park05_12.wav.npy (145/55563)
# Loaded 000256_0020_park05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0021_park06_12.wav.npy (146/55563)
# Loaded 000256_0021_park06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_0022_park07_12.wav.npy (147/55563)
# Loaded 000256_0022_park07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000256_
_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000615_0030_tube06_12.wav.npy (186/55563)
# Loaded 000615_0030_tube06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0000_tube07_12.wav.npy (187/55563)
# Loaded 000620_0000_tube07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0001_tube08_12.wav.npy (188/55563)
# Loaded 000620_0001_tube08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0002_tube09_12.wav.npy (189/55563)
# Loaded 000620_0002_tube09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0003_tube10_12.wav.npy (190/55563)
# Loaded 000620_0003_tube10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0004_tubestation01_12.wav.npy (191/55563)
# Loaded 000620_0004_tubestation01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0005_tubestation02_12.wav.npy (192/55563)
# Loaded 000620_0005_tubestation02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0006_tubestation03_12.wav.npy (193/55563)
# Loaded 000620_0006_tubestation03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0007_tubestation04_12.wav.npy (194/55563)
# Loaded 000620_0007_tubestation04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0008_tubestation05_12.wav.npy (195/55563)
# Loaded 000620_0008_tubestation05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0009_tubestation06_12.wav.npy (196/55563)
# Loaded 000620_0009_tubestation06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0010_tubestation07_12.wav.npy (197/55563)
# Loaded 000620_0010_tubestation07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0011_tubestation08_12.wav.npy (198/55563)
# Loaded 000620_0011_tubestation08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0012_tubestation09_12.wav.npy (199/55563)
# Loaded 000620_0012_tubestation09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0013_tubestation10_12.wav.npy (200/55563)
# Loaded 000620_0013_tubestation10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0014_bus01_12.wav.npy (201/55563)
# Loaded 000620_0014_bus01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0015_bus02_12.wav.npy (202/55563)
# Loaded 000620_0015_bus02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0016_bus03_12.wav.npy (203/55563)
# Loaded 000620_0016_bus03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0017_bus04_12.wav.npy (204/55563)
# Loaded 000620_0017_bus04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0018_bus05_12.wav.npy (205/55563)
# Loaded 000620_0018_bus05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0019_bus06_12.wav.npy (206/55563)
# Loaded 000620_0019_bus06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0020_bus07_12.wav.npy (207/55563)
# Loaded 000620_0020_bus07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0021_bus08_12.wav.npy (208/55563)
# Loaded 000620_0021_bus08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0022_bus09_12.wav.npy (209/55563)
# Loaded 000620_0022_bus09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0023_bus10_12.wav.npy (210/55563)
# Loaded 000620_0023_bus10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0024_busystreet01_12.wav.npy (211/55563)
# Loaded 000620_0024_busystreet01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0025_busystreet02_12.wav.npy (212/55563)
# Loaded 000620_0025_busystreet02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0026_busystreet03_12.wav.npy (213/55563)
# Loaded 000620_0026_busystreet03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0027_busystreet04_12.wav.npy (214/55563)
# Loaded 000620_0027_busystreet04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0028_busystreet05_12.wav.npy (215/55563)
# Loaded 000620_0028_busystreet05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0029_busystreet06_12.wav.npy (216/55563)
# Loaded 000620_0029_busystreet06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000620_0030_busystreet07_12.wav.npy (217/55563)
# Loaded 000620_0030_busystreet07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0000_busystreet08_12.wav.npy (218/55563)
# Loaded 000667_0000_busystreet08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0001_busystreet09_12.wav.npy (219/55563)
# Loaded 000667_0001_busystreet09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0002_busystreet10_12.wav.npy (220/55563)
# Loaded 000667_0002_busystreet10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0003_office01_12.wav.npy (221/55563)
# Loaded 000667_0003_office01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0004_office02_12.wav.npy (222/55563)
# Loaded 000667_0004_office02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0005_office03_12.wav.npy (223/55563)
# Loaded 000667_0005_office03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0006_office04_12.wav.npy (224/55563)
# Loaded 000667_0006_office04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_0007_office05_12.wav.npy (225/55563)
# Loaded 000667_0007_office05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000667_
_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0016_restaurant05_12.wav.npy (265/55563)
# Loaded 000690_0016_restaurant05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0017_restaurant06_12.wav.npy (266/55563)
# Loaded 000690_0017_restaurant06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0018_restaurant07_12.wav.npy (267/55563)
# Loaded 000690_0018_restaurant07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0019_restaurant08_12.wav.npy (268/55563)
# Loaded 000690_0019_restaurant08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0020_restaurant09_12.wav.npy (269/55563)
# Loaded 000690_0020_restaurant09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0021_restaurant10_12.wav.npy (270/55563)
# Loaded 000690_0021_restaurant10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0022_supermarket01_12.wav.npy (271/55563)
# Loaded 000690_0022_supermarket01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0023_supermarket02_12.wav.npy (272/55563)
# Loaded 000690_0023_supermarket02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0024_supermarket03_12.wav.npy (273/55563)
# Loaded 000690_0024_supermarket03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0025_supermarket04_12.wav.npy (274/55563)
# Loaded 000690_0025_supermarket04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0026_supermarket05_12.wav.npy (275/55563)
# Loaded 000690_0026_supermarket05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0027_supermarket06_12.wav.npy (276/55563)
# Loaded 000690_0027_supermarket06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0028_supermarket07_12.wav.npy (277/55563)
# Loaded 000690_0028_supermarket07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0029_supermarket08_12.wav.npy (278/55563)
# Loaded 000690_0029_supermarket08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000690_0030_supermarket09_12.wav.npy (279/55563)
# Loaded 000690_0030_supermarket09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0000_supermarket10_12.wav.npy (280/55563)
# Loaded 000695_0000_supermarket10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0001_tube01_12.wav.npy (281/55563)
# Loaded 000695_0001_tube01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0002_tube02_12.wav.npy (282/55563)
# Loaded 000695_0002_tube02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0003_tube03_12.wav.npy (283/55563)
# Loaded 000695_0003_tube03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0004_tube04_12.wav.npy (284/55563)
# Loaded 000695_0004_tube04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0005_tube05_12.wav.npy (285/55563)
# Loaded 000695_0005_tube05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0006_tube06_12.wav.npy (286/55563)
# Loaded 000695_0006_tube06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0007_tube07_12.wav.npy (287/55563)
# Loaded 000695_0007_tube07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0008_tube08_12.wav.npy (288/55563)
# Loaded 000695_0008_tube08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0009_tube09_12.wav.npy (289/55563)
# Loaded 000695_0009_tube09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0010_tube10_12.wav.npy (290/55563)
# Loaded 000695_0010_tube10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0011_tubestation01_12.wav.npy (291/55563)
# Loaded 000695_0011_tubestation01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0012_tubestation02_12.wav.npy (292/55563)
# Loaded 000695_0012_tubestation02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0013_tubestation03_12.wav.npy (293/55563)
# Loaded 000695_0013_tubestation03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0014_tubestation04_12.wav.npy (294/55563)
# Loaded 000695_0014_tubestation04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0015_tubestation05_12.wav.npy (295/55563)
# Loaded 000695_0015_tubestation05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0016_tubestation06_12.wav.npy (296/55563)
# Loaded 000695_0016_tubestation06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0017_tubestation07_12.wav.npy (297/55563)
# Loaded 000695_0017_tubestation07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0018_tubestation08_12.wav.npy (298/55563)
# Loaded 000695_0018_tubestation08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0019_tubestation09_12.wav.npy (299/55563)
# Loaded 000695_0019_tubestation09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0020_tubestation10_12.wav.npy (300/55563)
# Loaded 000695_0020_tubestation10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0021_bus01_12.wav.npy (301/55563)
# Loaded 000695_0021_bus01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0022_bus02_12.wav.npy (302/55563)
# Loaded 000695_0022_bus02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0023_bus03_12.wav.npy (303/55563)
# Loaded 000695_0023_bus03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0024_bus04_12.wav.npy (304/55563)
# Loaded 000695_0024_bus04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0025_bus05_12.wav.npy (305/55563)
# Loaded 000695_0025_bus05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0026_bus06_12.wav.npy (306/55563)
# Loaded 000695_0026_bus06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0027_bus07_12.wav.npy (307/55563)
# Loaded 000695_0027_bus07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0028_bus08_12.wav.npy (308/55563)
# Loaded 000695_0028_bus08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0029_bus09_12.wav.npy (309/55563)
# Loaded 000695_0029_bus09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000695_0030_bus10_12.wav.npy (310/55563)
# Loaded 000695_0030_bus10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0000_busystreet01_12.wav.npy (311/55563)
# Loaded 000704_0000_busystreet01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0001_busystreet02_12.wav.npy (312/55563)
# Loaded 000704_0001_busystreet02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0002_busystreet03_12.wav.npy (313/55563)
# Loaded 000704_0002_busystreet03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0003_busystreet04_12.wav.npy (314/55563)
# Loaded 000704_0003_busystreet04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0004_busystreet05_12.wav.npy (315/55563)
# Loaded 000704_0004_busystreet05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0005_busystreet06_12.wav.npy (316/55563)
# Loaded 000704_0005_busystreet06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0006_busystreet07_12.wav.npy (317/55563)
# Loaded 000704_0006_busystreet07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0007_busystreet08_12.wav.npy (318/55563)
# Loaded 000704_0007_busystreet08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0008_busystreet09_12.wav.npy (319/55563)
# Loaded 000704_0008_busystreet09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0009_busystreet10_12.wav.npy (320/55563)
# Loaded 000704_0009_busystreet10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0010_office01_12.wav.npy (321/55563)
# Loaded 000704_0010_office01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0011_office02_12.wav.npy (322/55563)
# Loaded 000704_0011_office02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0012_office03_12.wav.npy (323/55563)
# Loaded 000704_0012_office03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0013_office04_12.wav.npy (324/55563)
# Loaded 000704_0013_office04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0014_office05_12.wav.npy (325/55563)
# Loaded 000704_0014_office05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0015_office06_12.wav.npy (326/55563)
# Loaded 000704_0015_office06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0016_office07_12.wav.npy (327/55563)
# Loaded 000704_0016_office07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0017_office08_12.wav.npy (328/55563)
# Loaded 000704_0017_office08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0018_office09_12.wav.npy (329/55563)
# Loaded 000704_0018_office09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0019_office10_12.wav.npy (330/55563)
# Loaded 000704_0019_office10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0020_openairmarket01_12.wav.npy (331/55563)
# Loaded 000704_0020_openairmarket01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0021_openairmarket02_12.wav.npy (332/55563)
# Loaded 000704_0021_openairmarket02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0022_openairmarket03_12.wav.npy (333/55563)
# Loaded 000704_0022_openairmarket03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0023_openairmarket04_12.wav.npy (334/55563)
# Loaded 000704_0023_openairmarket04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0024_openairmarket05_12.wav.npy (335/55563)
# Loaded 000704_0024_openairmarket05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0025_openairmarket06_12.wav.npy (336/55563)
# Loaded 000704_0025_openairmarket06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0026_openairmarket07_12.wav.npy (337/55563)
# Loaded 000704_0026_openairmarket07_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0027_openairmarket08_12.wav.npy (338/55563)
# Loaded 000704_0027_openairmarket08_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0028_openairmarket09_12.wav.npy (339/55563)
# Loaded 000704_0028_openairmarket09_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0029_openairmarket10_12.wav.npy (340/55563)
# Loaded 000704_0029_openairmarket10_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000704_0030_park01_12.wav.npy (341/55563)
# Loaded 000704_0030_park01_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000705_0000_park02_12.wav.npy (342/55563)
# Loaded 000705_0000_park02_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000705_0001_park03_12.wav.npy (343/55563)
# Loaded 000705_0001_park03_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 000705_
12.wav.npy, shape: (1, 24, 3072)
# Trying to load 010481_0029_quietstreet04_12.wav.npy (3254/55563)
# Loaded 010481_0029_quietstreet04_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 010481_0030_quietstreet05_12.wav.npy (3255/55563)
# Loaded 010481_0030_quietstreet05_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 010535_0000_quietstreet06_12.wav.npy (3256/55563)
# Loaded 010535_0000_quietstreet06_12.wav.npy, shape: (1, 24, 3072)
# Trying to load 010535_0001_quietstreet07_12.wav.npy (3257/55563)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       9 print(f"Trying to load {emb_file} ({i+1}/{len(embedding_files)})")
#      10 try:
# ---> 11     arr = np.load(emb_path)
#      12     print(f"Loaded {emb_file}, shape: {arr.shape}")
#      13 except Exception as e:
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/numpy/lib/npyio.py:456, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453         return format.open_memmap(file, mode=mmap_mode,
#     454                                   max_header_size=max_header_size)
#     455     else:
# --> 456         return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                  pickle_kwargs=pickle_kwargs,
#     458                                  max_header_size=max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
#
# File ~/miniconda3/envs/audio_rep/lib/python3.10/site-packages/numpy/lib/format.py:809, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     806 else:
#     807     if isfileobj(fp):
#     808         # We can use the fast fromfile() function.
# --> 809         array = numpy.fromfile(fp, dtype=dtype, count=count)
#     810     else:
#     811         # This is not a real file. We have to read it the
#     812         # memory-intensive way.
#    (...)
#     820         # not correctly instantiate zero-width string dtypes; see
#     821         # https://github.com/numpy/numpy/pull/6430
#     822         array = numpy.ndarray(count, dtype=dtype)
#
# KeyboardInterrupt:

# %%
import os
import numpy as np

features_dir = '/home/melan/supervised-vs-SSL/data/results/byola/final_embeddings'
embedding_files = sorted([f for f in os.listdir(features_dir) if f.endswith('.npy')])

batch_size = 1000
num_batches = len(embedding_files) // batch_size + 1

for batch_idx in range(num_batches):
    batch_files = embedding_files[batch_idx*batch_size : (batch_idx+1)*batch_size]
    X_batch = []
    file_basenames_batch = []
    for emb_file in batch_files:
        emb_path = os.path.join(features_dir, emb_file)
        try:
            arr = np.load(emb_path)
            X_batch.append(arr.flatten())
            file_basenames_batch.append(os.path.splitext(emb_file)[0])
        except Exception as e:
            print(f"Error loading {emb_file}: {e}")
    X_batch = np.array(X_batch)
    np.save(f'batch_{batch_idx}.npy', X_batch)
    print(f"Saved batch {batch_idx+1}/{num_batches}, batch size: {len(X_batch)}")
# Out:
# Saved batch 1/69, batch size: 1000
# Saved batch 2/69, batch size: 1000
# Saved batch 3/69, batch size: 1000
# Saved batch 4/69, batch size: 1000
# Saved batch 5/69, batch size: 1000
# Saved batch 6/69, batch size: 1000
# Saved batch 7/69, batch size: 1000
# Saved batch 8/69, batch size: 1000
# Saved batch 9/69, batch size: 1000
# Saved batch 10/69, batch size: 1000
# Saved batch 11/69, batch size: 1000
# Saved batch 12/69, batch size: 1000
# Saved batch 13/69, batch size: 1000
# Saved batch 14/69, batch size: 1000
# Saved batch 15/69, batch size: 1000
# Saved batch 16/69, batch size: 1000
# Saved batch 17/69, batch size: 1000
# Saved batch 18/69, batch size: 1000
# Saved batch 19/69, batch size: 1000
# Saved batch 20/69, batch size: 1000
# Saved batch 21/69, batch size: 1000
# Saved batch 22/69, batch size: 1000
# Saved batch 23/69, batch size: 1000
# Saved batch 24/69, batch size: 1000
# Saved batch 25/69, batch size: 1000
# Saved batch 26/69, batch size: 1000
# Saved batch 27/69, batch size: 1000
# Saved batch 28/69, batch size: 1000
# Saved batch 29/69, batch size: 1000
# Saved batch 30/69, batch size: 1000
# Saved batch 31/69, batch size: 1000
# Saved batch 32/69, batch size: 1000
# Saved batch 33/69, batch size: 1000
# Saved batch 34/69, batch size: 1000
# Saved batch 35/69, batch size: 1000
# Saved batch 36/69, batch size: 1000
# Saved batch 37/69, batch size: 1000
# Saved batch 38/69, batch size: 1000
# Saved batch 39/69, batch size: 1000
# Saved batch 40/69, batch size: 1000
# Saved batch 41/69, batch size: 1000
# Saved batch 42/69, batch size: 1000
# Saved batch 43/69, batch size: 1000
# Saved batch 44/69, batch size: 1000
# Saved batch 45/69, batch size: 1000
# Saved batch 46/69, batch size: 1000
# Saved batch 47/69, batch size: 1000
# Saved batch 48/69, batch size: 1000
# Saved batch 49/69, batch size: 1000
# Saved batch 50/69, batch size: 1000
# Saved batch 51/69, batch size: 1000
# Saved batch 52/69, batch size: 1000
# Saved batch 53/69, batch size: 1000
# Saved batch 54/69, batch size: 1000
# Saved batch 55/69, batch size: 1000
# Saved batch 56/69, batch size: 1000
# Saved batch 57/69, batch size: 1000
# Saved batch 58/69, batch size: 1000
# Saved batch 59/69, batch size: 1000
# Saved batch 60/69, batch size: 1000
# Saved batch 61/69, batch size: 1000
# Saved batch 62/69, batch size: 1000
# Saved batch 63/69, batch size: 1000
# Saved batch 64/69, batch size: 1000
# Saved batch 65/69, batch size: 1000
# Saved batch 66/69, batch size: 1000
# Saved batch 67/69, batch size: 1000
# Saved batch 68/69, batch size: 1000
# Saved batch 69/69, batch size: 307

# %%
import os
import numpy as np
import sys
sys.path.append('/home/melan/supervised-vs-SSL/data/results/byola')

features_dir = '/final_embeddings_batches'
embedding_files = sorted([f for f in os.listdir(features_dir) if f.startswith('batch_') and f.endswith('.npy') and not f.endswith('_basenames.npy')])

for batch_file in embedding_files:
    batch_path = os.path.join(features_dir, batch_file)
    # Find all .npy files that went into this batch
    # If you have a record of which files went into each batch, use that.
    # Otherwise, try to reconstruct basenames from the batch file itself:
    # If you saved batches from a list of files, you should have saved basenames at batch creation.
    # If not, you need to reconstruct them. Here's a placeholder for how you might do it:
    # For example, if you have a list of original files per batch:
    # file_basenames_batch = [...]  # List of basenames for this batch
    # np.save(os.path.join(features_dir, batch_file.replace('.npy', '_basenames.npy')), file_basenames_batch)
    print(f"TODO: Save basenames for {batch_file} as {batch_file.replace('.npy', '_basenames.npy')}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 import numpy as np
#       4 features_dir = '/home/melan/supervised-vs-SSL/data/results/byola/final_embeddings_batches'
# ----> 5 embedding_files = sorted([f for f in os.listdir(features_dir) if f.startswith('batch_') and f.endswith('.npy') and not f.endswith('_basenames.npy')])
#       7 for batch_file in embedding_files:
#       8     batch_path = os.path.join(features_dir, batch_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/melan/supervised-vs-SSL/data/results/byola/final_embeddings_batches'
