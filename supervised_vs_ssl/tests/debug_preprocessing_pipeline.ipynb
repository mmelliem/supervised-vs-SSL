# %%
import numpy as np
import os

spec_dir = '/home/mellie/supervised-vs-SSL/data/byola_features/z_final_embeddings'
spec_files = sorted([f for f in os.listdir(spec_dir) if f.endswith('.npy')])

def infer_params(spec):
    print(f"Spec shape: {spec.shape}")
    
    if spec.ndim == 2:
        # 2D spectrogram (n_mels, n_frames)
        n_mels, n_frames = spec.shape
    elif spec.ndim == 3:
        # 3D array
        n_mels, n_frames = spec.shape[-2], spec.shape[-1]
        spec = spec.squeeze()
    elif spec.ndim == 1:
        # 1D array
        n_mels = 1
        n_frames = len(spec)
        spec = spec.reshape(1, -1)
    elif spec.ndim == 4:
        # 4D array
        n_mels, n_frames = spec.shape[-2], spec.shape[-1]
        flat_spec = spec.reshape(-1) # flatten
        
        params = {
            "n_mels": n_mels,
            "n_frames": n_frames,
            "dtype": spec.dtype,
            "min": float(flat_spec.min()),
            "max": float(flat_spec.max()),
            "mean": float(flat_spec.mean()),
            "std": float(flat_spec.std()),
            "original_shape": spec.shape # keep original shape
        }
        return params
    else:
        raise ValueError(f"Unexpected spectrogram shape: {spec.shape}")
    
    params = {
        "n_mels": n_mels,
        "n_frames": n_frames,
        "dtype": spec.dtype,
        "min": float(spec.min()),
        "max": float(spec.max()),
        "mean": float(spec.mean()),
        "std": float(spec.std()),
        "original_shape": spec.shape if hasattr(spec, 'shape') else None
    }
    return params

for f in spec_files[:3]:
    spec = np.load(os.path.join(spec_dir, f))
    params = infer_params(spec)
    print(f"File: {f}")
    print(f"  Shape: {params['n_mels']} (n_mels), {params['n_frames']} (n_frames)")
    print(f"  Dtype: {params['dtype']}")
    print(f"  Min: {params['min']:.4f}, Max: {params['max']:.4f}")
    print(f"  Mean: {params['mean']:.4f}, Std: {params['std']:.4f}")
    print("-" * 40)
# Out:
# Spec shape: (1, 24, 3072)
# File: 000200_0009_supermarket02_12.wav.npy
#   Shape: 24 (n_mels), 3072 (n_frames)
#   Dtype: float32
#   Min: 0.0000, Max: 1.9389
#   Mean: 0.0834, Std: 0.1831
# ----------------------------------------
# Spec shape: (1, 24, 3072)
# File: 000695_0004_tube04_12.wav.npy
#   Shape: 24 (n_mels), 3072 (n_frames)
#   Dtype: float32
#   Min: 0.0000, Max: 1.8905
#   Mean: 0.0899, Std: 0.1931
# ----------------------------------------
# Spec shape: (1, 24, 3072)
# File: 000709_0016_tube09_12.wav.npy
#   Shape: 24 (n_mels), 3072 (n_frames)
#   Dtype: float32
#   Min: 0.0000, Max: 1.8650
#   Mean: 0.0854, Std: 0.1848
# ----------------------------------------
